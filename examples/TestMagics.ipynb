# %% [markdown]
# # Setup

# %%
import sys
sys.path.append("..")

# %%
# %load_ext vule_sparkmagic
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %register spark

# %% [markdown]
# # Load source table

# %%
source_table = %load_table csv ./Housing.csv

# %% [markdown]
# # Query

# %%
col1 = 'price'
col2 = 'bathrooms'
threshold = 2

# %% [markdown]
# ## Short query

# %%
price_in_area = %sql SELECT price, area FROM source_table
# %show price_in_area -n 5
# Out:
#       price  area
# 0  13300000  7420
# 1  12250000  8960
# 2  12250000  9960
# 3  12215000  7500
# 4  11410000  7420

# %%
price_bathrooms = %sql SELECT {col1}, {col2} FROM source_table
# %show price_bathrooms -n 5
# Out:
#       price  bathrooms
# 0  13300000          2
# 1  12250000          4
# 2  12250000          2
# 3  12215000          2
# 4  11410000          1

# %% [markdown]
# ## Long query

# %%
# %%sql df
# SELECT
#     *
# FROM source_table

# %%
# %show df -n 10
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
# %show df
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
# %%sql
# SELECT
#     {col1}
#     , {col2}
# FROM source_table
# WHERE {col2} > {threshold}
# Out:
#       price  bathrooms
# 0  12250000          4
# 1  10850000          3
# 2  10150000          3
# 3  10150000          3
# 4   9681000          3
# 5   8190000          3
# 6   6440000          3
# 7   5530000          3
# 8   4970000          3
# 9   4200000          3

# %%
# %%sql -n 5
# SELECT
#     {col1}
#     , {col2}
# FROM source_table
# WHERE {col2} > {threshold}
# Out:
#       price  bathrooms
# 0  12250000          4
# 1  10850000          3
# 2  10150000          3
# 3  10150000          3
# 4   9681000          3

# %%
# %%sql df1
# SELECT
#     {col1}
#     , {col2}
# FROM source_table
# WHERE {col2} > {threshold}

# %%
# %show df1 -n 5
# Out:
#       price  bathrooms
# 0  12250000          4
# 1  10850000          3
# 2  10150000          3
# 3  10150000          3
# 4   9681000          3
